# %% [markdown]
# # *Informações sobre o desenvolvimento e uso da API*

# %% [markdown]
# ## **Criadores**

# %% [markdown]
# ### Abdul Malik
# ### Ana Beatriz Macedo
# ### Bruna Bellini
# ### Heloisa Mariani

# %% [markdown]
# ## **História do desenvolvimento da API**

# %% [markdown]
# ## **Instalações necessárias para utilização**

# %% [markdown]
# ## **Como utilizar**

# %%
import pandas as pd
df = pd.read_csv('./Data/df_final_aeronautico.csv', sep=';')
df.drop('Unnamed: 0', inplace=True, axis=1)
df
# Out:
#       aeronave_matricula aeronave_tipo_veiculo          aeronave_fabricante  \
# 0                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 1                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 2                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 3                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 4                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# ...                  ...                   ...                          ...
# 11282              PTUXD                 AVIÃO                      EMBRAER
# 11283              PTUXD                 AVIÃO                      EMBRAER
# 11284              PTUXD                 AVIÃO                      EMBRAER
# 11285              PTUXD                 AVIÃO                      EMBRAER
# 11286              PTUXD                 AVIÃO                      EMBRAER
#
#       aeronave_modelo aeronave_tipo_icao aeronave_motor_tipo  \
# 0            EMB-711A               P28R              PISTÃO
# 1            EMB-711A               P28R              PISTÃO
# 2            EMB-711A               P28R              PISTÃO
# 3            EMB-711A               P28R              PISTÃO
# 4            EMB-711A               P28R              PISTÃO
# ...               ...                ...                 ...
# 11282         EMB-202               IPAN              PISTÃO
# 11283         EMB-202               IPAN              PISTÃO
# 11284         EMB-202               IPAN              PISTÃO
# 11285         EMB-202               IPAN              PISTÃO
# 11286         EMB-202               IPAN              PISTÃO
#
#       aeronave_motor_quantidade  aeronave_pmd  aeronave_pmd_categoria  \
# 0                     MONOMOTOR          1202                    1202
# 1                     MONOMOTOR          1202                    1202
# 2                     MONOMOTOR          1202                    1202
# 3                     MONOMOTOR          1202                    1202
# 4                     MONOMOTOR          1202                    1202
# ...                         ...           ...                     ...
# 11282                 MONOMOTOR          1800                    1800
# 11283                 MONOMOTOR          1800                    1800
# 11284                 MONOMOTOR          1800                    1800
# 11285                 MONOMOTOR          1800                    1800
# 11286                 MONOMOTOR          1800                    1800
#
#        aeronave_assentos  ...  ocorrencia_tipo ocorrencia_tipo_categoria  \
# 0                    4.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 1                    4.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 2                    4.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 3                    4.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 4                    4.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# ...                  ...  ...              ...                       ...
# 11282                1.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 11283                1.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 11284                1.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 11285                1.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
# 11286                1.0  ...        PANE SECA   COMBUSTÍVEL | PANE SECA
#
#       taxonomia_tipo_icao     recomendacao_numero recomendacao_dia_assinatura  \
# 0                    FUEL                095/2011                  2011-07-21
# 1                    FUEL                096/2011                  2011-07-21
# 2                    FUEL                095/2011                  2011-07-21
# 3                    FUEL                096/2011                  2011-07-21
# 4                    FUEL                095/2011                  2011-07-21
# ...                   ...                     ...                         ...
# 11282                FUEL  A-146/CENIPA/2020 - 02                  2021-07-08
# 11283                FUEL  A-146/CENIPA/2020 - 03                  2021-07-08
# 11284                FUEL  A-146/CENIPA/2020 - 01                  2021-07-08
# 11285                FUEL  A-146/CENIPA/2020 - 02                  2021-07-08
# 11286                FUEL  A-146/CENIPA/2020 - 03                  2021-07-08
#
#       recomendacao_dia_encaminhamento  \
# 0                          2011-08-01
# 1                          2011-08-01
# 2                          2011-08-01
# 3                          2011-08-01
# 4                          2011-08-01
# ...                               ...
# 11282                      2021-07-26
# 11283                      2021-07-26
# 11284                      2021-07-26
# 11285                      2021-07-26
# 11286                      2021-07-26
#
#                                    recomendacao_conteudo  recomendacao_status  \
# 0      Revisar os requisitos de experiência recente p...         NÃO CUMPRIDA
# 1      Divulgar o presente relatório final aos operad...             CUMPRIDA
# 2      Revisar os requisitos de experiência recente p...         NÃO CUMPRIDA
# 3      Divulgar o presente relatório final aos operad...             CUMPRIDA
# 4      Revisar os requisitos de experiência recente p...         NÃO CUMPRIDA
# ...                                                  ...                  ...
# 11282  Atuar junto à empresa Plá e Silva Aviação Agrí...  AGUARDANDO RESPOSTA
# 11283  Divulgar os ensinamentos colhidos na presente ...  AGUARDANDO RESPOSTA
# 11284  Atuar junto à empresa Plá e Silva Aviação Agrí...  AGUARDANDO RESPOSTA
# 11285  Atuar junto à empresa Plá e Silva Aviação Agrí...  AGUARDANDO RESPOSTA
# 11286  Divulgar os ensinamentos colhidos na presente ...  AGUARDANDO RESPOSTA
#
#       recomendacao_destinatario_sigla          recomendacao_destinatario
# 0                                ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 1                                ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 2                                ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 3                                ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 4                                ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# ...                               ...                                ...
# 11282                            ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 11283                            ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 11284                            ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 11285                            ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 11286                            ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
#
# [11287 rows x 51 columns]

# %%
df_mh = df[['ocorrencia_dia','ocorrencia_hora']]
novo_df = df_mh['ocorrencia_dia'].str.split("/", n=2, expand= True).astype(int)
df_mh['mes_ocorrencia']= novo_df[1]
df_mh['ano_ocorrencia']= novo_df[2]
df_mh.drop('ocorrencia_dia', axis=1, inplace= True)
m = df_mh['mes_ocorrencia'].value_counts().index.tolist()[0]
a = df_mh['ano_ocorrencia'].value_counts().index.tolist()[0]
h = df_mh['ocorrencia_hora'].value_counts().index.tolist()[0] 
print(f'Top mês, dia e hora das ocorrências: \nMês: {m}\nAno: {a}\nHora: {h}')
# Out:
# Top mês, dia e hora das ocorrências:
# Mês: 8
# Ano: 2010
# Hora: 12:26:00
# <ipython-input-22-bb667e8d27eb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mh['mes_ocorrencia']= novo_df[1]
# <ipython-input-22-bb667e8d27eb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mh['ano_ocorrencia']= novo_df[2]
