# %% [markdown]
# # Framework sobre acidentes aeronaúticos

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd # importando a biblioteca pandas como a sigla pd
import numpy as np # importando a biblioteca numpy como a sigla np

# %% [markdown]
# ## Leitura dos Datasets

# %%
df_aeronave = pd.read_csv('./Data/aeronave.csv', sep=';') # leitura do arquivo csv a partir da biblioteca pandas e o comando read_csv
df_aeronave # chamada da várivael onde foi armaenado o dataframe
# Out:
#       codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                  39115              PTNQX                         ***
# 1                  39155              PTLVI                         ***
# 2                  39156              PPPTO                         ***
# 3                  39158              PRLGJ                     REGULAR
# 4                  39176              PRMAA                     REGULAR
# ...                  ...                ...                         ...
# 6183               80249              PRAJY                         ***
# 6184               80251              PRAJY                         ***
# 6185               80257              PRLBR                         ***
# 6186               80258              PTRXE                         ***
# 6187               80259              PRYRE                         ***
#
#      aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
df_fator_contribuinte = pd.read_csv('./Data/fator_contribuinte.csv', sep=';')
df_fator_contribuinte
# Out:
#       codigo_ocorrencia3                   fator_nome  \
# 0                  39115        APLICAÇÃO DE COMANDOS
# 1                  39115      JULGAMENTO DE PILOTAGEM
# 2                  39115                    PERCEPÇÃO
# 3                  39115          PLANEJAMENTO DE VOO
# 4                  39115  POUCA EXPERIÊNCIA DO PILOTO
# ...                  ...                          ...
# 4480               79713                      ATITUDE
# 4481               79713      JULGAMENTO DE PILOTAGEM
# 4482               79713                      MEMÓRIA
# 4483               79713           PROCESSO DECISÓRIO
# 4484               79713         SUPERVISÃO GERENCIAL
#
#                  fator_aspecto   fator_condicionante         fator_area
# 0     DESEMPENHO DO SER HUMANO  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 1     DESEMPENHO DO SER HUMANO  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 2          ASPECTO PSICOLÓGICO            INDIVIDUAL       FATOR HUMANO
# ...

# %%
df_ocorrencia_tipo = pd.read_csv('./Data/ocorrencia_tipo.csv', sep=';')
df_ocorrencia_tipo
# Out:
#       codigo_ocorrencia1                                    ocorrencia_tipo  \
# 0                  39115                                          PANE SECA
# 1                  39155                           VAZAMENTO DE COMBUSTÍVEL
# 2                  39156                                        FOGO EM VOO
# 3                  39158                                   SUPERAQUECIMENTO
# 4                  39176  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...
# ...                  ...                                                ...
# 6278               80251  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...
# 6279               80257                                      INDETERMINADO
# 6280               80258                                  COLISÃO COM FAUNA
# 6281               80258                                  EXCURSÃO DE PISTA
# 6282               80259                FALHA OU MAU FUNCIONAMENTO DO MOTOR
#
# ...

# %%
df_ocorrencia = pd.read_csv('./Data/ocorrencia.csv', sep=';')
df_ocorrencia
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %%
df_recomendacao = pd.read_csv('./Data/recomendacao.csv', sep=';')
df_recomendacao
# Out:
#       codigo_ocorrencia4     recomendacao_numero recomendacao_dia_assinatura  \
# 0                  39115                095/2011                  2011-07-21
# 1                  39115                096/2011                  2011-07-21
# 2                  39156                063/2011                  2011-06-30
# 3                  39156                064/2011                  2011-06-30
# 4                  39235                205/2011                  2011-08-29
# ...                  ...                     ...                         ...
# 1867               79665  IG-118/CENIPA/2019 -02                  2020-10-29
# 1868               79692  A-140/CENIPA/2020 - 01                  2021-07-21
# 1869               79713  A-146/CENIPA/2020 - 01                  2021-07-08
# 1870               79713  A-146/CENIPA/2020 - 02                  2021-07-08
# 1871               79713  A-146/CENIPA/2020 - 03                  2021-07-08
#
# ...

# %% [markdown]
# ## Juntando Datasets

# %%
df_1 = df_aeronave.merge(df_ocorrencia, left_on='codigo_ocorrencia2', right_on='codigo_ocorrencia2') # juntando 
df_1
# Out:
#       codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                  39115              PTNQX                         ***
# 1                  39155              PTLVI                         ***
# 2                  39156              PPPTO                         ***
# 3                  39158              PRLGJ                     REGULAR
# 4                  39176              PRMAA                     REGULAR
# ...                  ...                ...                         ...
# 6183               80249              PRAJY                         ***
# 6184               80251              PRAJY                         ***
# 6185               80257              PRLBR                         ***
# 6186               80258              PTRXE                         ***
# 6187               80259              PRYRE                         ***
#
#      aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
df_2 = df_1.merge(df_fator_contribuinte, left_on='codigo_ocorrencia3', right_on='codigo_ocorrencia3')
df_2
# Out:
#       codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                  39115              PTNQX                         ***
# 1                  39115              PTNQX                         ***
# 2                  39115              PTNQX                         ***
# 3                  39115              PTNQX                         ***
# 4                  39115              PTNQX                         ***
# ...                  ...                ...                         ...
# 4539               79713              PTUXD                         ***
# 4540               79713              PTUXD                         ***
# 4541               79713              PTUXD                         ***
# 4542               79713              PTUXD                         ***
# 4543               79713              PTUXD                         ***
#
#      aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
df_3 = df_2.merge(df_ocorrencia_tipo, left_on='codigo_ocorrencia1', right_on='codigo_ocorrencia1')
df_3
# Out:
#       codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                  39115              PTNQX                         ***
# 1                  39115              PTNQX                         ***
# 2                  39115              PTNQX                         ***
# 3                  39115              PTNQX                         ***
# 4                  39115              PTNQX                         ***
# ...                  ...                ...                         ...
# 4810               79713              PTUXD                         ***
# 4811               79713              PTUXD                         ***
# 4812               79713              PTUXD                         ***
# 4813               79713              PTUXD                         ***
# 4814               79713              PTUXD                         ***
#
#      aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
df_4 = df_3.merge(df_recomendacao, left_on='codigo_ocorrencia4', right_on='codigo_ocorrencia4')
df_4
# Out:
#        codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                   39115              PTNQX                         ***
# 1                   39115              PTNQX                         ***
# 2                   39115              PTNQX                         ***
# 3                   39115              PTNQX                         ***
# 4                   39115              PTNQX                         ***
# ...                   ...                ...                         ...
# 11300               79713              PTUXD                         ***
# 11301               79713              PTUXD                         ***
# 11302               79713              PTUXD                         ***
# 11303               79713              PTUXD                         ***
# 11304               79713              PTUXD                         ***
#
#       aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
df_4.drop(['codigo_ocorrencia3', 'codigo_ocorrencia4', 'codigo_ocorrencia2', 'aeronave_operador_categoria', 'codigo_ocorrencia1', 'investigacao_aeronave_liberada', 'recomendacao_dia_feedback','ocorrencia_aerodromo'], axis=1,inplace=True)
df_4
# Out:
#       aeronave_matricula aeronave_tipo_veiculo          aeronave_fabricante  \
# 0                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 1                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 2                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 3                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 4                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# ...                  ...                   ...                          ...
# 11300              PTUXD                 AVIÃO                      EMBRAER
# 11301              PTUXD                 AVIÃO                      EMBRAER
# 11302              PTUXD                 AVIÃO                      EMBRAER
# 11303              PTUXD                 AVIÃO                      EMBRAER
# 11304              PTUXD                 AVIÃO                      EMBRAER
#
# ...

# %%
df_4 = df_4[df_4.divulgacao_relatorio_numero.notnull()]
df_4 = df_4[df_4.divulgacao_dia_publicacao.notnull()]
df_4 = df_4[df_4.recomendacao_conteudo.notnull()]
df_4
# Out:
#       aeronave_matricula aeronave_tipo_veiculo          aeronave_fabricante  \
# 0                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 1                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 2                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 3                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 4                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# ...                  ...                   ...                          ...
# 11300              PTUXD                 AVIÃO                      EMBRAER
# 11301              PTUXD                 AVIÃO                      EMBRAER
# 11302              PTUXD                 AVIÃO                      EMBRAER
# 11303              PTUXD                 AVIÃO                      EMBRAER
# 11304              PTUXD                 AVIÃO                      EMBRAER
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df_4 = df_4.replace("****", np.nan)
df_4
# Out:
#       aeronave_matricula aeronave_tipo_veiculo          aeronave_fabricante  \
# 0                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 1                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 2                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 3                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# 4                  PTNQX                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA
# ...                  ...                   ...                          ...
# 11300              PTUXD                 AVIÃO                      EMBRAER
# 11301              PTUXD                 AVIÃO                      EMBRAER
# 11302              PTUXD                 AVIÃO                      EMBRAER
# 11303              PTUXD                 AVIÃO                      EMBRAER
# 11304              PTUXD                 AVIÃO                      EMBRAER
#
# ...

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11287 entries, 0 to 11304
# Data columns (total 51 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   aeronave_matricula               11287 non-null  object
#  1   aeronave_tipo_veiculo            11287 non-null  object
#  2   aeronave_fabricante              11287 non-null  object
#  3   aeronave_modelo                  11287 non-null  object
#  4   aeronave_tipo_icao               11287 non-null  object
#  5   aeronave_motor_tipo              11287 non-null  object
#  6   aeronave_motor_quantidade        11287 non-null  object
#  7   aeronave_pmd                     11287 non-null  int64
#  8   aeronave_pmd_categoria           11287 non-null  int64
#  9   aeronave_assentos                11241 non-null  float64
#  10  aeronave_ano_fabricacao          11244 non-null  float64
#  11  aeronave_pais_fabricante         11287 non-null  object
# ...

# %%
df_4.to_csv('./Data/df_final_aeronautico.csv', sep=';', index = False)
